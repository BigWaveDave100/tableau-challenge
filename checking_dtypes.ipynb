# %%
import pandas as pd
import numpy as np

# %%
csv18 = "JC-201809-citibike-tripdata.csv"
csv19 = "JC-201909-citibike-tripdata.csv"
bike_2018 = pd.read_csv(csv18)
bike_2019 = pd.read_csv(csv19)

# %%
bike_2018.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
# 1           370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
# 2          1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
# 3           383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
# 4           377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3267        Morris Canal
# ...

# %%
bike_2019.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           145  2019-09-01 00:00:37.6920  2019-09-01 00:03:03.0100
# 1           212  2019-09-01 00:03:00.6000  2019-09-01 00:06:33.3420
# 2           569  2019-09-01 00:07:13.0020  2019-09-01 00:16:42.8610
# 3          1380  2019-09-01 00:07:25.3350  2019-09-01 00:30:26.1640
# 4          1346  2019-09-01 00:07:56.4670  2019-09-01 00:30:22.5440
#
#    start station id start station name  start station latitude  \
# 0              3640     Journal Square               40.733670
# 1              3194    McGinley Square               40.725340
# 2              3214   Essex Light Rail               40.712774
# 3              3214   Essex Light Rail               40.712774
# 4              3214   Essex Light Rail               40.712774
#
#    start station longitude  end station id            end station name  \
# 0               -74.062500            3206                     Hilltop
# ...

# %%
bike_2018.shape[0]
bike_2019.shape[0]
# Out:
# 49244

# %%
bike_2018.info()
bike_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39022 entries, 0 to 39021
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             39022 non-null  int64
#  1   starttime                39022 non-null  object
#  2   stoptime                 39022 non-null  object
#  3   start station id         39022 non-null  int64
#  4   start station name       39022 non-null  object
#  5   start station latitude   39022 non-null  float64
#  6   start station longitude  39022 non-null  float64
#  7   end station id           39022 non-null  int64
#  8   end station name         39022 non-null  object
#  9   end station latitude     39022 non-null  float64
#  10  end station longitude    39022 non-null  float64
#  11  bikeid                   39022 non-null  int64
#  12  usertype                 39022 non-null  object
#  13  birth year               39022 non-null  int64
# ...
